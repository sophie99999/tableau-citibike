# %%
import pandas as pd

# %%
df_201901="Data Resources/JC-201901-citibike-tripdata.csv"
df_Jan=pd.read_csv(df_201901)
len(df_Jan)
# Out:
# 19676

# %%
df_201902="Data Resources/JC-201902-citibike-tripdata.csv"
df_Feb=pd.read_csv(df_201902)
len(df_Feb)
# Out:
# 18565

# %%
df_201903="Data Resources/JC-201903-citibike-tripdata.csv"
df_Mar=pd.read_csv(df_201903)
len(df_Mar)
# Out:
# 23606

# %%
df_201904="Data Resources/JC-201904-citibike-tripdata.csv"
df_Apr=pd.read_csv(df_201904)
len(df_Apr)
# Out:
# 33056

# %%
df_201905="Data Resources/JC-201905-citibike-tripdata 2.csv"
df_May=pd.read_csv(df_201905)
len(df_May)
# Out:
# 36135

# %%
df_201906="Data Resources/JC-201906-citibike-tripdata.csv"
df_Jun=pd.read_csv(df_201906)
len(df_Jun)
# Out:
# 39430

# %%
df_Janfeb=pd.concat([df_Jan,df_Feb])
df_Janfeb
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# 5               737  2019-01-01 12:56:53.2040  2019-01-01 13:09:11.0400
# 6               917  2019-01-01 13:03:44.7760  2019-01-01 13:19:02.7690
# 7              3248  2019-01-01 13:12:03.1280  2019-01-01 14:06:12.0400
# 8              3168  2019-01-01 13:13:12.0450  2019-01-01 14:06:00.4110
# 9               353  2019-01-01 17:07:44.6670  2019-01-01 17:13:38.2640
# 10              503  2019-01-01 17:34:50.9580  2019-01-01 17:43:14.3190
# 11              285  2019-01-01 18:06:03.1680  2019-01-01 18:10:48.5380
# ...

# %%
df_Janfeb.to_csv("Jan_Feb.csv",index=False)

# %%
df_Janjun=pd.concat([df_Jan,df_Feb,df_Mar,df_Apr,df_May,df_Jun])
df_Janjun
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# 5               737  2019-01-01 12:56:53.2040  2019-01-01 13:09:11.0400
# 6               917  2019-01-01 13:03:44.7760  2019-01-01 13:19:02.7690
# 7              3248  2019-01-01 13:12:03.1280  2019-01-01 14:06:12.0400
# 8              3168  2019-01-01 13:13:12.0450  2019-01-01 14:06:00.4110
# 9               353  2019-01-01 17:07:44.6670  2019-01-01 17:13:38.2640
# 10              503  2019-01-01 17:34:50.9580  2019-01-01 17:43:14.3190
# 11              285  2019-01-01 18:06:03.1680  2019-01-01 18:10:48.5380
# ...

# %%
df_Janjun.to_csv("Jan_Jun_sixmonths.csv",index=False)
